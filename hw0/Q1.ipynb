# %% [markdown]
# ## Proprocess the text to list

# %%
import sys

# %%
words = open(sys.argv[1], 'r') # Or directly import the file "words.txt
words_list = list(map(str.strip,words.read().split(' '))) # remove the leading and trailing space
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-71-25ebdd25fe3c> in <module>()
# ----> 1 words = open(sys.argv[1], 'r')
#       2 words_list = list(map(str.strip,words.read().split(' '))) # remove the leading and trailing space
#
# FileNotFoundError: [Errno 2] No such file or directory: '-f'

# %% [markdown]
# ## Add each word into dictionary and keey the order

# %%
from collections import OrderedDict
words_count_dict = OrderedDict()

for word in words_list:
    if word not in words_count_dict:
        words_count_dict[word] = 1
    else:
        words_count_dict[word] += 1
words_count_dict
# Out:
# OrderedDict([('Singaporeans', 2),
#              ('were', 1),
#              ('meant', 1),
#              ('to', 18),
#              ('go', 1),
#              ('the', 29),
#              ('polls', 1),
#              ('at', 3),
#              ('end', 1),
#              ('of', 14),
#              ('next', 1),
#              ('week', 1),
#              ('vote', 1),
#              ('for', 8),
#              ('a', 13),
#              ('new', 6),
#              ('president', 4),
#              ('but', 3),
#              ('theyll', 1),
#              ('no', 2),
#              ('longer', 1),
#              ('have', 3),
#              ('chance', 1),
#              ('with', 3),
#              ('only', 5),
#              ('one', 3),
#              ('candidate', 1),
#              ('qualifying', 1),
#              ('races', 1),
#              ('Former', 1),
#              ('Speaker', 1),
#              ('Parliament', 1),
#              ('Halimah', 5),
#              ('Yacob', 2),
#              ('has', 5),
#              ('emerged', 1),
#              ('victorious', 1),
#              ('by', 2),
#              ('defaults', 1),
#              ('after', 1),
#              ('other', 2),
#              ('presidential', 4),
#              ('hopefuls', 2),
#              ('fell', 1),
#              ('foul', 1),
#              ('ruless', 1),
#              ('I', 3),
#              ('can', 2),
#              ('say', 1),
#              ('that', 7),
#              ('promise', 1),
#              ('do', 1),
#              ('best', 1),
#              ('serve', 1),
#              ('people', 1),
#              ('Singapore', 3),
#              ('and', 12),
#              ('doesnt', 1),
#              ('change', 1),
#              ('whether', 1),
#              ('there', 1),
#              ('is', 3),
#              ('an', 1),
#              ('election', 4),
#              ('or', 4),
#              ('electionss', 1),
#              ('she', 2),
#              ('told', 3),
#              ('reporters', 1),
#              ('Mondays', 1),
#              ('What', 1),
#              ('should', 1),
#              ('be', 3),
#              ('moment', 1),
#              ('celebration', 1),
#              ('ss', 4),
#              ('will', 1),
#              ('Singapores', 7),
#              ('first', 2),
#              ('female', 1),
#              ('proved', 1),
#              ('contentious', 1),
#              ('several', 1),
#              ('reasons', 1),
#              ('appears', 1),
#              ('odds', 1),
#              ('reputation', 1),
#              ('as', 4),
#              ('technocratic', 1),
#              ('efficient', 1),
#              ('city', 1),
#              ('states', 1),
#              ('While', 1),
#              ('office', 2),
#              ('largely', 1),
#              ('ceremonial', 1),
#              ('role', 1),
#              ('in', 6),
#              ('he', 1),
#              ('power', 1),
#              ('veto', 1),
#              ('some', 1),
#              ('governments', 2),
#              ('decisionss', 1),
#              ('example', 1),
#              ('fiscal', 1),
#              ('matters', 1),
#              ('touch', 1),
#              ('on', 3),
#              ('countrys', 2),
#              ('reservess', 1),
#              ('key', 1),
#              ('appointments', 1),
#              ('public', 1),
#              ('services', 1),
#              ('The', 5),
#              ('beneficiaries', 1),
#              ('from', 5),
#              ('this', 2),
#              ('reserved', 1),
#              ('are', 5),
#              ('her', 2),
#              ('teams', 1),
#              ('well', 1),
#              ('oppositions', 1),
#              ('which', 2),
#              ('now', 1),
#              ('line', 1),
#              ('attack', 1),
#              ('against', 2),
#              ('PAP', 1),
#              ('rest', 1),
#              ('sufferedss', 1),
#              ('Sudhir', 1),
#              ('Vadakeths', 1),
#              ('author', 1),
#              ('commentators', 1),
#              ('CNNs', 1),
#              ('wass', 1),
#              ('until', 1),
#              ('recentlys', 1),
#              ('loyal', 1),
#              ('member', 1),
#              ('ruling', 2),
#              ('PAPs', 1),
#              ('dominates', 1),
#              ('Singaporean', 2),
#              ('politics', 1),
#              ('All', 1),
#              ('unhappy', 1),
#              ('meritocracy', 2),
#              ('electoral', 1),
#              ('fairnesss', 1),
#              ('core', 1),
#              ('valuess', 1),
#              ('been', 1),
#              ('eroded', 1),
#              ('fulfill', 1),
#              ('perceived', 1),
#              ('political', 1),
#              ('goals', 1),
#              ('In', 2),
#              ('elections', 2),
#              ('times', 1),
#              ('candidates', 2),
#              ('become', 1),
#              ('could', 2),
#              ('come', 1),
#              ('racial', 1),
#              ('groups', 1),
#              ('Malay', 3),
#              ('Its', 1),
#              ('radical', 1),
#              ('policy', 1),
#              ('would', 1),
#              ('likely', 1),
#              ('prove', 1),
#              ('divisive', 1),
#              ('elsewhere', 1),
#              ('its', 2),
#              ('Southeast', 1),
#              ('Asian', 1),
#              ('nation', 1),
#              ('said', 1),
#              ('was', 1),
#              ('necessary', 1),
#              ('ensure', 1),
#              ('better', 1),
#              ('representation', 1),
#              ('among', 1),
#              ('three', 1),
#              ('main', 1),
#              ('racess', 1),
#              ('Chineses', 2),
#              ('Indian', 2),
#              ('It', 1),
#              ('shows', 1),
#              ('we', 3),
#              ('dont', 1),
#              ('talk', 2),
#              ('about', 2),
#              ('multisracialisms', 1),
#              ('it', 1),
#              ('context', 1),
#              ('opportunities', 1),
#              ('everyones', 1),
#              ('actually', 1),
#              ('practice', 1),
#              ('itss', 1),
#              ('Straits', 1),
#              ('Times', 1),
#              ('newspapers', 1),
#              ('before', 1),
#              ('declaring', 1),
#              ('intention', 1),
#              ('contest', 1),
#              ('rules', 2),
#              ('also', 1),
#              ('set', 1),
#              ('stricter', 1),
#              ('criteria', 1),
#              ('background', 1),
#              ('candidatess', 1),
#              ('For', 1),
#              ('examples', 1),
#              ('those', 1),
#              ('private', 1),
#              ('sector', 1),
#              ('required', 1),
#              ('chief', 1),
#              ('executive', 1),
#              ('companys', 1),
#              ('least', 1),
#              ('million', 1),
#              ('shareholders', 1),
#              ('equity', 1),
#              ('two', 1),
#              ('businessmen', 1),
#              ('Salleh', 1),
#              ('Marican', 1),
#              ('Farid', 1),
#              ('Khan', 1),
#              ('failed', 1),
#              ('gain', 1),
#              ('Certificates', 1),
#              ('Eligibility', 1),
#              ('Presidential', 2),
#              ('Elections', 2),
#              ('Committee', 2),
#              ('these', 1),
#              ('groundss', 1),
#              ('although', 1),
#              ('exercised', 1),
#              ('discretion', 1),
#              ('allow', 1),
#              ('them', 1),
#              ('run', 2),
#              ('Critics', 1),
#              ('charge', 1),
#              ('way', 1),
#              ('government', 1),
#              ('stages', 1),
#              ('manage', 1),
#              ('prevent', 1),
#              ('opponents', 1),
#              ('runnings', 1),
#              ('Augusts', 1),
#              ('appeal', 1),
#              ('court', 1),
#              ('ruled', 1),
#              ('legal', 1),
#              ('challenge', 1),
#              ('system', 1),
#              ('party', 1),
#              ('lawmaker', 1),
#              ('turned', 1),
#              ('critics', 1),
#              ('Tan', 2),
#              ('Cheng', 1),
#              ('Bocks', 1),
#              ('had', 1),
#              ('narrowly', 1),
#              ('lost', 1),
#              ('previous', 1),
#              ('Tony', 1),
#              ('Tans', 1),
#              ('former', 1),
#              ('deputy', 1),
#              ('prime', 1),
#              ('minister', 1),
#              ('widely', 1),
#              ('recognized', 1),
#              ('favored', 1),
#              ('planned', 1),
#              ('agains', 1),
#              ('population', 1),
#              ('Malays', 1),
#              ('ambiguously', 1),
#              ('named', 1),
#              ('Other', 1)])

# %% [markdown]
# ## Output the words count to txt file

# %%
output_file = open('Q1.txt', 'w')
for index, (word, count) in enumerate(words_count_dict.items()):
    if index != len(words_count_dict)-1:
        output_file.writelines(f'{word} {index} {count}\n')
    else:
        output_file.writelines(f'{word} {index} {count}')
output_file.close()
